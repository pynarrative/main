# %% [markdown]
# **Importing libraries**

# %%
import pynarrative as pn
import altair as alt
import pandas as pd

#Importing template
from pynarrative.templates.mytemplates.inflationTemplate import inflationTemplate

# %% [markdown]
# **Importing fonts**
#
# This cell contains the font URLs from Google Fonts, which are essential for displaying the correct font in the template.

# %%
# %%html
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Inter:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Lato:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Lora:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Merriweather:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Noto+Sans:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Nunito:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Oswald:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Playfair+Display:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Poppins:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Raleway:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Roboto+Condensed:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Ubuntu:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Bricolage+Grotesque:opsz,wght@12..96,400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Cinzel+Decorative:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Space+Grotesk:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Pacifico&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Syne:wght@400;700&display=swap');
# </style>
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Inter:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Lato:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Lora:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Merriweather:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Noto+Sans:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Nunito:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Oswald:wght@400;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Playfair+Display:wght@400;700&display=swap');
# ...

# %% [markdown]
# **Creating dataframes**
#
# Data source: *Source: Organization for Economic Co-operation and Development via statista.com*

# %%
year = [
    1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
    1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
    1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
    1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
    2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
    2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025
]

inflation_rate = [
    3.38, 1.32, 2.86, -0.51, 2.35, 2.05, 4.69, 7.45, 5.91, 4.52, 2.35, 3.73,
    1.28, 2.66, 4.97, 4.79, 5.75, 10.8, 19.16, 16.95, 16.61, 17.13, 12.09, 14.8,
    21.06, 17.97, 16.48, 14.65, 10.79, 9.21, 5.82, 4.75, 5.06, 6.26, 6.46, 6.25,
    5.27, 4.63, 4.05, 5.24, 4.01, 2.04, 1.96, 1.66, 2.54, 2.79, 2.47, 2.67,
    2.21, 1.99, 2.09, 1.83, 3.35, 0.77, 1.53, 2.78, 3.04, 1.22, 0.24, 0.04,
    -0.09, 1.23, 1.14, 0.61, -0.14, 1.87, 8.2, 5.62, 0.98, 1.53
]

inflation_italy = pd.DataFrame({
    "year" : year,
    "inflation_rate" : inflation_rate
})

# %% [markdown]
# Data story with **horizontal bar chart**

# %%
story = (
    pn.Story(
    #Builing the Story class object
        data = inflation_italy,
        width = 800,
        height = 400,
        template = inflationTemplate #Using inflationTemplate
    )

    #Method invocation
    #Line chart
    .mark_line()

    #Data encoding
    #To create a horizontal bar chart we plot the cathegorical data on Y and the numerical data on X
    .encode(
        x = alt.X(
            # 'year' must be encoded as Quantitative (:Q) instead of Ordinal (:O) or Nominal (:N) because 
            # numerical features like scale limits (domain=[1956, 2025]), number formatting (format="d"), 
            # and precise axis tick counts (tickCount=10) require continuous numeric values.
            "year:Q",
            title = "Year",
            axis = alt.Axis(
                format = "d",
                tickCount = 10,
            ),
            scale = alt.Scale(domain=[1956, 2025])
        ),
        y = alt.Y(
            "inflation_rate:Q",
            title = "Inflation rate (%)",
            axis = alt.Axis(grid =True)
        ),
    )
    
    #Data source
    .add_source(
        text = "Source: Organisation for Economic Co-operation and Development via statista.com",
        position = "top",
        align = "left"
    )
    
    #Title and subtitle
    .add_title(
        title = "Italy’s Inflation Rollercoaster (1956–2025)",
        subtitle = "Tracking seven decades of economic shifts, from the 1970s oil crises to modern post-pandemic peaks.",
        align = "center"
    )

    #Context area (on the right)
    .add_context(
        text = "Between the late 1970s and early 1980s, Italy experienced historic double-digit inflation peaks, driven primarily by energy shocks and wage-price spirals. Following the entry into the European Monetary System and subsequent reforms, rates steadily declined, remaining largely subdued until the recent post-2021 global supply chain disruptions and energy crisis pushed figures upward once again.",
        position = "top",
    )

    #Average line
    .add_line(
        value = inflation_italy["inflation_rate"],
        math = "mean",
        label_text = "Average inflation rate: 5.33%",
        color = "darkblue",
        label_font_size = 13
    )

    #Min line
    .add_line(
        value = inflation_italy["inflation_rate"],
        math = "min",
        label_text = "Minimum inflation rate: -0.51% (1959)",
        color = "darkgreen",
        label_font_size = 13
    )

    #Max line
    .add_line(
        value = inflation_italy["inflation_rate"],
        math = "max",
        label_text = "Maximum inflation rate: +21.06% (1980)",
        label_font_size = 13
    )


    .add_annotation(
        x = 1977,
        y = 15,
        text = "Severe inflationary pressures dominated the 1970s and 80s before structural reforms and the Adoption of the Euro stabilized rates near the 5.33% historical average.",
        background_color = "rgba(0, 0, 0, 0.4)",
        text_color = "white"
    )

    .add_annotation(
        x = 2007,
        y = 8,
        text = "Covid 19 pandemic",
    )


    #Next steps
    .add_next_steps(
        position = "right",
        mode = "vertical",
        title = "What can governments do?",
        steps = ["Implement targeted fiscal restraint to avoid overheating aggregate demand", "Diversify national energy supply to hedge against future fossil fuel price shocks", "Streamline market regulations to promote competition and lower consumer prices"],
    )

    .render()
)

story
# Out:
# Mean = 5.33
# Min = -0.51
# Max = 21.06
# alt.VConcatChart(...)

# %% [markdown]
# Data story with **bar chart**

# %%
story = (
    pn.Story(
    #Builing the Story class object
        data = inflation_italy,
        width = 800,
        height = 400,
        template = inflationTemplate #Using inflationTemplate
    )

    #Method invocation
    #Bar chart
    .mark_bar()

    #Data encoding
    #To create a horizontal bar chart we plot the cathegorical data on Y and the numerical data on X
    .encode(
        x = alt.X(
            # 'year' must be encoded as Quantitative (:Q) instead of Ordinal (:O) or Nominal (:N) because 
            # numerical features like scale limits (domain=[1956, 2025]), number formatting (format="d"), 
            # and precise axis tick counts (tickCount=10) require continuous numeric values.
            "year:Q",
            title = "Year",
            axis = alt.Axis(
                format = "d",
                tickCount = 10,
            ),
            scale = alt.Scale(domain=[1956, 2025])
        ),
        y = alt.Y(
            "inflation_rate:Q",
            title = "Inflation rate (%)",
            axis = alt.Axis(grid =True)
        ),
    )
    
    #Data source
    .add_source(
        text = "Source: Organisation for Economic Co-operation and Development via statista.com",
        position = "top",
        align = "left"
    )
    
    #Title and subtitle
    .add_title(
        title = "Italy’s Inflation Rollercoaster (1956–2025)",
        subtitle = "Tracking seven decades of economic shifts, from the 1970s oil crises to modern post-pandemic peaks.",
        align = "center"
    )

    #Context area (on the right)
    .add_context(
        text = "Between the late 1970s and early 1980s, Italy experienced historic double-digit inflation peaks, driven primarily by energy shocks and wage-price spirals. Following the entry into the European Monetary System and subsequent reforms, rates steadily declined, remaining largely subdued until the recent post-2021 global supply chain disruptions and energy crisis pushed figures upward once again.",
        position = "top",
    )

    #Average line
    .add_line(
        value = inflation_italy["inflation_rate"],
        math = "mean",
        label_text = "Average inflation rate: 5.33%",
        color = "darkblue",
        label_font_size = 13
    )

    #Min line
    .add_line(
        value = inflation_italy["inflation_rate"],
        math = "min",
        label_text = "Minimum inflation rate: -0.51% (1959)",
        color = "darkgreen",
        label_font_size = 13
    )

    #Max line
    .add_line(
        value = inflation_italy["inflation_rate"],
        math = "max",
        label_text = "Maximum inflation rate: +21.06% (1980)",
        label_font_size = 13
    )


    .add_annotation(
        x = 1977,
        y = 15,
        text = "Severe inflationary pressures dominated the 1970s and 80s before structural reforms and the Adoption of the Euro stabilized rates near the 5.33% historical average.",
        background_color = "rgba(0, 0, 0, 0.4)",
        text_color = "white"
    )

    .add_annotation(
        x = 2007,
        y = 8,
        text = "Covid 19 pandemic",
    )


    #Next steps
    .add_next_steps(
        position = "right",
        mode = "vertical",
        title = "What can governments do?",
        steps = ["Implement targeted fiscal restraint to avoid overheating aggregate demand", "Diversify national energy supply to hedge against future fossil fuel price shocks", "Streamline market regulations to promote competition and lower consumer prices"],
    )

    .render()
)

story
# Out:
# Mean = 5.33
# Min = -0.51
# Max = 21.06
# alt.VConcatChart(...)
